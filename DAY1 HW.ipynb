# %%
print("இவன்_ரௌத்திரன்");
# Out:
# இவன்_ரௌத்திரன்

# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %%
#A = 15
B = 10
print(A)
# Out:
# 15

# %%
#a = .5
b = .25
#x = 1
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       2 b = .25
#       3 #x = 1
# ----> 4 print(a)
#
# NameError: name 'a' is not defined

# %%
'''
VB = 5
S = 10
print(VB+S)
'''
# Out:
# '\nVB = 5\nS = 10\nprint(VB+S)\n'

# %%
python = 31
_py_thon= 32
python = 33
py_thon = 34
pYTHon = 35
PYTHON = 36
print(py_thon);
# Out:
# 34

# %%
1python = 23
pyt hon = 23
pyt-hon = 23
print(1python);
# Out:
#   Cell In[39], line 1
#     1python = 23
#     ^
# SyntaxError: invalid decimal literal

# %%
V = B = S = 510
print(S)
# Out:
# 510

# %%
t,s,f = "RAINA","DHONI","WHO"
print(s)
# Out:
# DHONI

# %%
x = 'VBS'
y = '510'
print(x+y)
# Out:
# VBS510

# %%
x = input()
y = input()
print(x+y)
# Out:
#  VBS
#  510
# VBS510
