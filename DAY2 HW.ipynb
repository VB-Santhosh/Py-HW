# %%
# INTEGER

a = 1510
print(type(a))
# Out:
# <class 'int'>

# %%
# FLOAT

a = 15.10
print(type(a))
# Out:
# <class 'float'>

# %%
#STRING

k = "welcome to python"
print(type(k))
# Out:
# <class 'str'>

# %%
# STRING

a = ''' NAMAE KARIYA ROJA , VEERAM ENNAVENDRU KATIDUVOM 
         NAMAE KARIYA ROJA'''
print(a)
print(type(a))
# Out:
#  NAMAE KARIYA ROJA , VEERAM ENNAVENDRU KATIDUVOM
#          NAMAE KARIYA ROJA
# <class 'str'>

# %%
# COMPLEX

a = 510+10j
print(type(a))
# Out:
# <class 'complex'>

# %%
a = 510+10j
print(a.real)
print(a.imag)
# Out:
# 510.0
# 10.0

# %%
CASTING:

# %%
a = int(10.89)
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
a = str(510)
print(a)
print(type(a))
# Out:
# 510
# <class 'str'>

# %%
a = float(25)
print(a)
print(type(a))
# Out:
# 25.0
# <class 'float'>

# %%
a = complex(510)
print(a)
print(type(a))
# Out:
# (510+0j)
# <class 'complex'>

# %%
#INTEGER

a = 510
a1 = float(a)
a2 = str(a)
a3 = complex(a)
print(a1)
print(a2)
print(a3)
# Out:
# 510.0
# 510
# (510+0j)

# %%
#FLOAT

v = 15.10
v1 = int(v)
v2 = str(v)
v3 = complex(v)
print(v1)
print(v2)
print(v3)
# Out:
# 15
# 15.1
# (15.1+0j)

# %%
# COMPLEX

s = 15+10j
print(s)
#s1 = int(s)
#s2 = float(s)
s3 = str(s)
#print(s1)
#print(s2)
print(s3)
# Out:
# (15+10j)
# (15+10j)

# %%
s = 15+10j
print(s)
s1 = int(s)
#s2 = float(s)
s3 = str(s)
print(s1)
#print(s2)
#print(s3)
# Out:
# (15+10j)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 s = 15+10j
#       2 print(s)
# ----> 3 s1 = int(s)
#       4 #s2 = float(s)
#       5 s3 = str(s)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
s = 15+10j
print(s)
#s1 = int(s)
s2 = float(s)
s3 = str(s)
#print(s1)
print(s2)
#print(s3)
# Out:
# (15+10j)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 4
#       2 print(s)
#       3 #s1 = int(s)
# ----> 4 s2 = float(s)
#       5 s3 = str(s)
#       6 #print(s1)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
x = str(input("enter the no:"))
print(x)
print(type(x))
# Out:
# enter the no: 510vbs
# 510vbs
# <class 'str'>

# %%
x = float(input("enter the no:"))
print(x)
print(type(x))
# Out:
# enter the no: 510
# 510.0
# <class 'float'>

# %%
x = int(input("enter the no:"))
print(x)
print(type(x))
# Out:
# enter the no: 510
# 510
# <class 'int'>

# %%
x = complex(input("enter the no:"))
print(x)
print(type(x))
# Out:
# enter the no: 510
# (510+0j)
# <class 'complex'>

# %%
# STRING

# %%
#STRING LENGTH:

y = 'python'
print(len(y))
# Out:
# 6

# %%
x = """ Late at night, Emma found an old, 
    dusty key hidden under a loose floorboard.
    Curiosity led her to the attic, 
    where she discovered a locked chest that seemed to hum with energy. 
    As she turned the key, the chest creaked open, 
    revealing a portal to a world she never imagined . """
print(len(x))
# Out:
# 300

# %%
# STRING INDEXING:

z = "We Use Python"
print(z[5])
# Out:
# e

# %%
z = "We Use Python"
print(z[-3])
# Out:
# h

# %%
z = "We Use Python"
print(z[7])
print(z[-5])
# Out:
# P
# y

# %%
# STRING SLICING:

z = "We Use Python"
print(z[:6])
# Out:
# We Use

# %%
z = "We Use Python"
print(z[-6:-1])
# Out:
# Pytho

# %%
z = "We Use Python"
print(z[7:13])
# Out:
# Python

# %%
z = "We Use Python"
print(z[3:6])
# Out:
# Use

# %%
z = "We Use Python"
print(z[-11:-4])
# Out:
#  Use Py
